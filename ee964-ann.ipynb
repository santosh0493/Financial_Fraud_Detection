# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc, RocCurveDisplay, precision_recall_curve, PrecisionRecallDisplay, confusion_matrix


# Assuming you've loaded the data into df
df = pd.read_csv('/kaggle/input/financial-statement-fraud-data/Final_Dataset.csv')

# Convert labels to binary
le = LabelEncoder()
df['Fraud'] = le.fit_transform(df['Fraud'])

# Split data into train, validation, and test sets
train, temp = train_test_split(df, test_size=0.3, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)

# TF-IDF vectorization
vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(train['Fillings']).toarray()
X_val = vectorizer.transform(val['Fillings']).toarray()
X_test = vectorizer.transform(test['Fillings']).toarray()

y_train = train['Fraud'].values
y_val = val['Fraud'].values
y_test = test['Fraud'].values

# Define the ANN Model:
# model = Sequential()
# model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
# model.add(Dropout(0.5))
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1, activation='sigmoid'))

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Hyperparameter Change 

# model = Sequential()

# # Input Layer
# model.add(Dense(512, activation='relu', input_shape=(X_train.shape[1],)))
# model.add(Dropout(0.5))

# # Hidden Layer 1
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))

# # Hidden Layer 2
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))

# # Output Layer
# model.add(Dense(1, activation='sigmoid'))

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model = Sequential()

# Input Layer
model.add(Dense(256, activation='tanh', input_shape=(X_train.shape[1],)))

# Hidden Layer 1
model.add(Dense(128, activation='tanh'))

# Hidden Layer 2
model.add(Dense(64, activation='tanh'))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])



# Train the Model:

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train, y_train, 
    epochs=20, 
    batch_size=32, 
    validation_data=(X_val, y_val), 
    callbacks=[early_stop]
)

# Evaluate the Model:

# Validation performance
y_val_pred = (model.predict(X_val) > 0.5).astype("int32")
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred)
val_recall = recall_score(y_val, y_val_pred)
val_f1 = f1_score(y_val, y_val_pred)

# Test performance
y_test_pred = (model.predict(X_test) > 0.5).astype("int32")
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)

print(f"Validation Accuracy: {val_accuracy:.4f}")
print(f"Validation Precision: {val_precision:.4f}")
print(f"Validation Recall: {val_recall:.4f}")
print(f"Validation F1-score: {val_f1:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test F1-score: {test_f1:.4f}")

# Define and Train the Model (ReLU Activation)
model_relu = Sequential()
model_relu.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model_relu.add(Dense(128, activation='relu'))
model_relu.add(Dense(64, activation='relu'))
model_relu.add(Dense(1, activation='sigmoid'))
model_relu.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history_relu = model_relu.fit(
    X_train, y_train, 
    epochs=20, 
    batch_size=32, 
    validation_data=(X_val, y_val), 
    callbacks=[early_stop]
)

# Define and Train the Model (Tanh Activation)
model_tanh = Sequential()
model_tanh.add(Dense(256, activation='tanh', input_shape=(X_train.shape[1],)))
model_tanh.add(Dense(128, activation='tanh'))
model_tanh.add(Dense(64, activation='tanh'))
model_tanh.add(Dense(1, activation='sigmoid'))
model_tanh.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

history_tanh = model_tanh.fit(
    X_train, y_train, 
    epochs=20, 
    batch_size=32, 
    validation_data=(X_val, y_val), 
    callbacks=[early_stop]
)

# Evaluate and Plot Graphs
def evaluate_and_plot(model, X_test, y_test):
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    
    # Plot Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Non-Fraudulent", "Fraudulent"])
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

    # Plot ROC Curve
    y_probas = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test, y_probas)
    roc_auc = auc(fpr, tpr)
    roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='Model')
    roc_display.plot()
    plt.title('ROC Curve')
    plt.show()

    # Plot Precision-Recall Curve
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_probas)
    pr_display = PrecisionRecallDisplay(precision=precision_curve, recall=recall_curve)
    pr_display.plot()
    plt.title('Precision-Recall Curve')
    plt.show()

print("Results for ReLU Activation:")
evaluate_and_plot(model_relu, X_test, y_test)

print("Results for Tanh Activation:")
evaluate_and_plot(model_tanh, X_test, y_test)
# Out:
# 2025-05-25 10:36:16.658918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748169376.924097      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748169376.997511      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-05-25 10:36:58.779079: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.6138 - loss: 0.6481 - val_accuracy: 0.6800 - val_loss: 0.6178
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7229 - loss: 0.5074 - val_accuracy: 0.8400 - val_loss: 0.3460
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8291 - loss: 0.3753 - val_accuracy: 0.9200 - val_loss: 0.2403
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9530 - loss: 0.2245 - val_accuracy: 0.8800 - val_loss: 0.3668
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8967 - loss: 0.2540 - val_accuracy: 0.8800 - val_loss: 0.2948
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9559 - loss: 0.1227 - val_accuracy: 0.8800 - val_loss: 0.1849
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9914 - loss: 0.0538 - val_accuracy: 0.8800 - val_loss: 0.2443
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 0.9200 - val_loss: 0.1619
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.9200 - val_loss: 0.1617
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8800 - val_loss: 0.2284
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9200 - val_loss: 0.1534
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9200 - val_loss: 0.1526
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9200 - val_loss: 0.1531
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9200 - val_loss: 0.1596
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9200 - val_loss: 0.1552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Validation Accuracy: 0.9200
# Validation Precision: 0.9000
# Validation Recall: 0.9000
# Validation F1-score: 0.9000
# Test Accuracy: 0.9231
# Test Precision: 0.8571
# Test Recall: 1.0000
# Test F1-score: 0.9231
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.4797 - loss: 0.6903 - val_accuracy: 0.7200 - val_loss: 0.6666
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7074 - loss: 0.6576 - val_accuracy: 0.8400 - val_loss: 0.6125
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8066 - loss: 0.5982 - val_accuracy: 0.8800 - val_loss: 0.5376
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8330 - loss: 0.5311 - val_accuracy: 0.8000 - val_loss: 0.4803
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8386 - loss: 0.4123 - val_accuracy: 0.8000 - val_loss: 0.4844
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8859 - loss: 0.3480 - val_accuracy: 0.8800 - val_loss: 0.3661
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9091 - loss: 0.2487 - val_accuracy: 0.8800 - val_loss: 0.2464
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9640 - loss: 0.1854 - val_accuracy: 0.8400 - val_loss: 0.3134
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9530 - loss: 0.1639 - val_accuracy: 0.9600 - val_loss: 0.2260
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9684 - loss: 0.1420 - val_accuracy: 0.9600 - val_loss: 0.1971
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9966 - loss: 0.0748 - val_accuracy: 0.8400 - val_loss: 0.2118
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9852 - loss: 0.0622 - val_accuracy: 0.8800 - val_loss: 0.2422
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0488 - val_accuracy: 0.8800 - val_loss: 0.2755
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.5700 - loss: 0.6736 - val_accuracy: 0.8800 - val_loss: 0.5687
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7700 - loss: 0.5552 - val_accuracy: 0.8400 - val_loss: 0.4088
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8642 - loss: 0.4094 - val_accuracy: 0.8800 - val_loss: 0.3467
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8909 - loss: 0.2808 - val_accuracy: 0.8400 - val_loss: 0.2749
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9120 - loss: 0.2526 - val_accuracy: 0.9600 - val_loss: 0.2043
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9699 - loss: 0.1330 - val_accuracy: 0.8400 - val_loss: 0.2187
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9495 - loss: 0.1422 - val_accuracy: 0.8800 - val_loss: 0.3802
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9852 - loss: 0.1026 - val_accuracy: 0.9200 - val_loss: 0.1617
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 0.9200 - val_loss: 0.1477
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.9200 - val_loss: 0.1455
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9200 - val_loss: 0.1562
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9200 - val_loss: 0.1408
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9200 - val_loss: 0.1395
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9200 - val_loss: 0.1457
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9200 - val_loss: 0.1383
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9200 - val_loss: 0.1396
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9200 - val_loss: 0.1414
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9200 - val_loss: 0.1523
# Results for ReLU Activation:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Accuracy: 0.7308
# Precision: 0.6316
# Recall: 1.0000
# F1-score: 0.7742
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Results for Tanh Activation:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Accuracy: 0.9231
# Precision: 0.8571
# Recall: 1.0000
# F1-score: 0.9231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
